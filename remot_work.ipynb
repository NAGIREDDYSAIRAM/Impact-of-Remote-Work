# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
remot_work=pd.read_csv("Impact_of_Remote_Work_on_Mental_Health.csv")

# %%
remot_work.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# ...

# %%
remot_work.shape
# Out:
# (5000, 20)

# %%
remot_work.head(10)
# Out:
#   Employee_ID  Age             Gender           Job_Role       Industry  \
# 0     EMP0001   32         Non-binary                 HR     Healthcare
# 1     EMP0002   40             Female     Data Scientist             IT
# 2     EMP0003   59         Non-binary  Software Engineer      Education
# 3     EMP0004   27               Male  Software Engineer        Finance
# 4     EMP0005   49               Male              Sales     Consulting
# 5     EMP0006   59         Non-binary              Sales             IT
# 6     EMP0007   31  Prefer not to say              Sales             IT
# 7     EMP0008   42         Non-binary     Data Scientist  Manufacturing
# 8     EMP0009   56  Prefer not to say     Data Scientist     Healthcare
# 9     EMP0010   30             Female                 HR             IT
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# ...

# %%
remot_work.describe()
# Out:
#                                   count     mean        std   min   25%   50%  \
# Age                              5000.0  40.9950  11.296021  22.0  31.0  41.0
# Years_of_Experience              5000.0  17.8102  10.020412   1.0   9.0  18.0
# Hours_Worked_Per_Week            5000.0  39.6146  11.860194  20.0  29.0  40.0
# Number_of_Virtual_Meetings       5000.0   7.5590   4.636121   0.0   4.0   8.0
# Work_Life_Balance_Rating         5000.0   2.9842   1.410513   1.0   2.0   3.0
# Social_Isolation_Rating          5000.0   2.9938   1.394615   1.0   2.0   3.0
# Company_Support_for_Remote_Work  5000.0   3.0078   1.399046   1.0   2.0   3.0
#
#                                   75%   max
# Age                              51.0  60.0
# Years_of_Experience              26.0  35.0
# Hours_Worked_Per_Week            50.0  60.0
# Number_of_Virtual_Meetings       12.0  15.0
# Work_Life_Balance_Rating          4.0   5.0
# Social_Isolation_Rating           4.0   5.0
# ...

# %%
remot_work.isnull().sum()
# Out:
# Employee_ID                             0
# Age                                     0
# Gender                                  0
# Job_Role                                0
# Industry                                0
# Years_of_Experience                     0
# Work_Location                           0
# Hours_Worked_Per_Week                   0
# Number_of_Virtual_Meetings              0
# Work_Life_Balance_Rating                0
# Stress_Level                            0
# Mental_Health_Condition              1196
# Access_to_Mental_Health_Resources       0
# Productivity_Change                     0
# Social_Isolation_Rating                 0
# Satisfaction_with_Remote_Work           0
# Company_Support_for_Remote_Work         0
# Physical_Activity                    1629
# Sleep_Quality                           0
# Region                                  0
# dtype: int64

# %%
remot_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
# ...

# %%
remot_work. Mental_Health_Condition.value_counts()
# Out:
# Mental_Health_Condition
# Burnout       2476
# Anxiety       1278
# Depression    1246
# Name: count, dtype: int64

# %%
remot_work.Mental_Health_Condition.fillna(remot_work.Mental_Health_Condition.mode()[0],inplace=True)

# %%
remot_work.Physical_Activity.fillna(remot_work.Physical_Activity.mode()[0],inplace=True)

# %%
remot_work.isnull().sum()
# Out:
# Employee_ID                          0
# Age                                  0
# Gender                               0
# Job_Role                             0
# Industry                             0
# Years_of_Experience                  0
# Work_Location                        0
# Hours_Worked_Per_Week                0
# Number_of_Virtual_Meetings           0
# Work_Life_Balance_Rating             0
# Stress_Level                         0
# Mental_Health_Condition              0
# Access_to_Mental_Health_Resources    0
# Productivity_Change                  0
# Social_Isolation_Rating              0
# Satisfaction_with_Remote_Work        0
# Company_Support_for_Remote_Work      0
# Physical_Activity                    0
# Sleep_Quality                        0
# Region                               0
# dtype: int64

# %%
data=remot_work.describe()
data=pd.DataFrame(data.T)

# %%
plt.figure(facecolor="orange",edgecolor="black")
sns.heatmap(data=data,annot=True,fmt=".0f",cmap="Blues")
plt.show()

# %%
corr=remot_work.select_dtypes(exclude="O").corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
remot_work.Gender.isnull().mean()
# Out:
# 0.0

# %%
Gender=remot_work.Gender.value_counts()
Gender
# Out:
# Gender
# Female               1274
# Male                 1270
# Prefer not to say    1242
# Non-binary           1214
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.pie(Gender,labels=Gender.index,autopct='%1.2f%%')
#plt.legend(loc="upper right")
plt.show()

# %%
orr=remot_work.Job_Role.value_counts(ascending=True).index

# %%
sns.countplot(remot_work.Job_Role,palette='viridis',order=orr)
plt.show()

# %%
remot_work.Industry.value_counts().index
# Out:
# Index(['Finance', 'IT', 'Healthcare', 'Retail', 'Education', 'Manufacturing',
#        'Consulting'],
#       dtype='object', name='Industry')

# %%
plt.figure(facecolor="orange")
sns.countplot(remot_work.Industry,
             order=remot_work.Industry.value_counts(ascending=True).index,
             palette="coolwarm")
plt.title("Frequency of different INDUSTRIES")
plt.show()

# %%
plt.figure(facecolor="red")
sns.countplot(data=remot_work,
           y=remot_work.Industry,hue=remot_work.Gender,
            edgecolor="blue")
plt.title("Gender in Every Industry")
plt.show()

# %%
remot_work.groupby(["Industry"])["Job_Role"].count()
# Out:
# Industry
# Consulting       680
# Education        690
# Finance          747
# Healthcare       728
# IT               746
# Manufacturing    683
# Retail           726
# Name: Job_Role, dtype: int64

# %%
remot_work.groupby(["Industry","Job_Role"])["Job_Role"].value_counts(ascending=False)
# Out:
# Industry       Job_Role
# Consulting     Data Scientist        92
#                Designer              92
#                HR                   109
#                Marketing             98
#                Project Manager       92
#                Sales                100
#                Software Engineer     97
# Education      Data Scientist        98
#                Designer             100
#                HR                    99
#                Marketing             72
#                Project Manager      126
#                Sales                 86
#                Software Engineer    109
# Finance        Data Scientist       104
#                Designer             112
#                HR                   118
#                Marketing            102
#                Project Manager      107
#                Sales                105
#                Software Engineer     99
# Healthcare     Data Scientist       104
#                Designer             122
# ...

# %%
sns.countplot(data=remot_work,
           y=remot_work.Industry,
              hue=remot_work.Job_Role)
plt.show()

# %%
sns.histplot(remot_work["Years_of_Experience"],facecolor="blue",edgecolor="pink",bins=20)
plt.show()

# %%
remot_work.Work_Location.value_counts()
# Out:
# Work_Location
# Remote    1714
# Hybrid    1649
# Onsite    1637
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.barplot(remot_work.Work_Location.value_counts(),facecolor="orange",edgecolor="yellow")
plt.show()

# %%
a=remot_work.groupby("Work_Location")["Industry"].count()

# %%
plt.figure(facecolor="yellow")
sns.countplot(remot_work,x=remot_work.Work_Location,hue="Industry",edgecolor="black")
plt.title("LOCATION  & INDUSTRY")
plt.show()

# %%
a=remot_work.Hours_Worked_Per_Week.value_counts(ascending=False).head()
plt.figure(figsize=(3,3))
sns.barplot(a,facecolor="red")
plt.show()

# %%
remot_work.Number_of_Virtual_Meetings.value_counts()
# Out:
# Number_of_Virtual_Meetings
# 15    347
# 7     329
# 10    328
# 0     327
# 9     324
# 2     320
# 8     316
# 12    315
# 14    311
# 4     306
# 5     303
# 13    301
# 3     297
# 1     294
# 11    292
# 6     290
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,3))
sns.barplot(remot_work.Number_of_Virtual_Meetings.value_counts().head())
plt.title("Number_of_Virtual_Meetings by an employee")
plt.show()

# %%
remot_work.Stress_Level.value_counts()
# Out:
# Stress_Level
# High      1686
# Medium    1669
# Low       1645
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,2),facecolor="pink")
sns.countplot(remot_work,y="Stress_Level",palette="coolwarm")
plt.title("Level of Stress")
plt.show()

# %%
remot_work.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Job_Role', 'Industry',
#        'Years_of_Experience', 'Work_Location', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
remot_work.Mental_Health_Condition.value_counts()
# Out:
# Mental_Health_Condition
# Burnout       1280
# Anxiety       1278
# Depression    1246
# Name: count, dtype: int64

# %%
remot_work.groupby(["Mental_Health_Condition","Stress_Level"])["Stress_Level"].count()
# Out:
# Mental_Health_Condition  Stress_Level
# Anxiety                  High            438
#                          Low             428
#                          Medium          412
# Burnout                  High            445
#                          Low             413
#                          Medium          422
# Depression               High            401
#                          Low             416
#                          Medium          429
# Name: Stress_Level, dtype: int64

# %%
plt.figure(figsize=(6,4),facecolor="#9dc209")
sns.countplot(remot_work,x="Mental_Health_Condition",hue="Stress_Level")
plt.show()

# %%
remot_work.Access_to_Mental_Health_Resources.value_counts()
# Out:
# Access_to_Mental_Health_Resources
# No     2553
# Yes    2447
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3),facecolor="pink")
plt.pie(remot_work.Access_to_Mental_Health_Resources.value_counts(),autopct="%1.1f%%",
        labels=remot_work.Access_to_Mental_Health_Resources.value_counts().index)
plt.title("Access to Mental Health Resources provided to employess")
plt.legend()
plt.show()

# %%
remot_work.Productivity_Change.value_counts().index
# Out:
# Index(['Decrease', 'No Change', 'Increase'], dtype='object', name='Productivity_Change')

# %%
remot_work.groupby(["Mental_Health_Condition","Productivity_Change"])["Mental_Health_Condition"].count()
# Out:
# Mental_Health_Condition  Productivity_Change
# Anxiety                  Decrease               422
#                          Increase               426
#                          No Change              430
# Burnout                  Decrease               431
#                          Increase               424
#                          No Change              425
# Depression               Decrease               461
#                          Increase               354
#                          No Change              431
# Name: Mental_Health_Condition, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(remot_work,x=remot_work.Work_Location,hue="Productivity_Change")
plt.title("Production According to Location")
plt.show()

# %%
remot_work.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Job_Role', 'Industry',
#        'Years_of_Experience', 'Work_Location', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
remot_work.Satisfaction_with_Remote_Work.value_counts()
# Out:
# Satisfaction_with_Remote_Work
# Unsatisfied    1677
# Satisfied      1675
# Neutral        1648
# Name: count, dtype: int64

# %%
remot_work.Access_to_Mental_Health_Resources.value_counts()
# Out:
# Access_to_Mental_Health_Resources
# No     2553
# Yes    2447
# Name: count, dtype: int64

# %%
remot_work.groupby(["Satisfaction_with_Remote_Work","Access_to_Mental_Health_Resources"])["Satisfaction_with_Remote_Work"].count()
# Out:
# Satisfaction_with_Remote_Work  Access_to_Mental_Health_Resources
# Neutral                        No                                   825
#                                Yes                                  823
# Satisfied                      No                                   874
#                                Yes                                  801
# Unsatisfied                    No                                   854
#                                Yes                                  823
# Name: Satisfaction_with_Remote_Work, dtype: int64

# %%
sns.countplot(remot_work,x="Satisfaction_with_Remote_Work",hue="Access_to_Mental_Health_Resources")
plt.show()

# %%
remot_work.Physical_Activity.value_counts()
# Out:
# Physical_Activity
# Weekly    1755
# Daily     1616
# Name: count, dtype: int64
